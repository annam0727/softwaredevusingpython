# %%
60 * 60
# Out:
# 3600

# %%
seconds_per_hour = 60 * 60 
seconds_per_hour
# Out:
# 3600

# %%
seconds_per_hour * 24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %%
Yes the results were equal to each other aside from the .0 for the floating-point result and the integer division answer not including that.
